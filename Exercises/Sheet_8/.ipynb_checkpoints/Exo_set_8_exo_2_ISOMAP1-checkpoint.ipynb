,6.054810747890607,9.919286065370787,7.28576107658812,13.896789280706408,11.006132295910811,7.12186443996743,5.733200763656073,12.027719953727933,12.08707031983014,11.890336766785651,13.330435289584319,10.919762460096251,10.069127236809054,6.613891584075285,11.293677270770067,13.686619293159367,13.100095354934531,14.076540764437283,12.428487779759175,9.850044358122176,8.965358252318138,13.105692737981338,13.885193533712734,10.305159000977168,8.162559838500304,7.7574847218945475,12.925359669069572,6.744692144828878,11.639084195919173,8.158267697039555,12.26731548404897,12.08949813674399,11.322507701281724,10.581920028285703,9.365238299636388 ...

# %%
#Conduct and plot PCA
pca = PCA(n_components=2 )
pCs = pca.fit_transform(X)
plt.scatter(x=pCs.T[0], y=pCs.T[1], c=c)

# %% [markdown]
# Because PCA uses euklidean distance as error which it minimizes, the form of the data which in the third dimensions is kept. We don't have the effect of unfolding which we would like to achieve with ISOMAP.

# %%
#Returns euklidean Distance
def euklidean_distance(x1,x2):
    return np.sqrt((x1[0]-x2[0])**2+(x1[1]-x2[1])**2+(x1[2]-x2[2])**2)
def get_weight_Matrix(X,c)   
D= np.zeros((len(c),len(c)))
for i1,x1 in enumerate(X):
    for i2, x2 in enumerate(X):
        D[i1,i2]=euklidean_distance(x1,x2)

# %%
def check_symmetrie(M):
    print(not np.any(M-M.T))
check_symmetrie(D)
# Out:
# True

# %%
def k_nearest_neighbors_graph(k, D):
    W = np.matrix(np.ones((len(c),len(c))) * np.inf)
    for i in range(len(c)):
        W[i,i]=0
    for i, w1 in enumerate(D):
        for j in np.argsort(w1)[1:k+1]:
            W[i, j] = w1[j]
    return W

# %%
W = k_nearest_neighbors_graph(3, D)
check_symmetrie(W)
# Out:
# False
# <ipython-input-128-053ed322b329>:2: RuntimeWarning:
#
# invalid value encountered in subtract

# %%
def get_epsilon_graph(epsilon, D):
    W = np.matrix(np.ones((len(c),len(c))) * np.inf)
    for i in range(len(c)):
        W[i,i]=0
    for i, w1 in enumerate(D):
        for j in np.argsort(w1)[1:]:
            if(w1[j]<=epsilon):
                W[i, j] = w1[j]
            else:
                break
    return W

# %%
W = get_epsilon_graph(10, D)
check_symmetrie(W)
# Out:
# False
# <ipython-input-128-053ed322b329>:2: RuntimeWarning:
#
# invalid value encountered in subtract

# %%
def floyd_warshall(W):   
    D = W.copy()
    n = D.shape[0]
    for k in range(n):
        for i in range(n):
            D[i,:] = np.minimum(D[i,:], D[i,k]+D[k,:])
    return D

# %%
D = floyd_warshall(W)
print(D)
# Out:
# [[ 0.         17.54963121 17.77925635 ... 11.6445183  14.03345033
#   13.21864036]
#  [17.54963121  0.         21.62435298 ... 22.87453411 14.35078802
#   22.49034092]
#  [17.77925635 21.62435298  0.         ...  8.35693463 30.62712416
#   19.11509604]
#  ...
#  [11.6445183  22.87453411  8.35693463 ...  0.         23.0425892
#   10.91603779]
#  [14.03345033 14.35078802 30.62712416 ... 23.0425892   0.
#   16.63623302]
#  [13.21864036 22.49034092 19.11509604 ... 10.91603779 16.63623302
#    0.        ]]
